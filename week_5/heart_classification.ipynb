# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv(r"C:/Users/beomgyu2/AI_CLASS/heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
Y = pd.get_dummies(y).values

# %%
Y
# Out:
# array([[False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False]])

# %%
X = X.values

# %%
X
# Out:
# array([[63.,  1.,  3., ...,  0.,  0.,  1.],
#        [37.,  1.,  2., ...,  0.,  0.,  2.],
#        [41.,  0.,  1., ...,  2.,  0.,  2.],
#        ...,
#        [68.,  1.,  0., ...,  1.,  2.,  3.],
#        [57.,  1.,  0., ...,  1.,  1.,  3.],
#        [57.,  0.,  1., ...,  1.,  1.,  2.]])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((242, 13), (61, 13), (242, 2), (61, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

model = Sequential()


model.add(Dense(32,input_shape=(13,),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(2,activation='softmax'))

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# C:\Users\beomgyu2\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              14 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 780 (3.05 KB)
#  Trainable params: 780 (3.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.5829 - loss: 6.1853 - val_accuracy: 0.6721 - val_loss: 1.0173
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5958 - loss: 1.9246 - val_accuracy: 0.5410 - val_loss: 1.6026
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6234 - loss: 1.7077 - val_accuracy: 0.7213 - val_loss: 0.7157
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6411 - loss: 1.1327 - val_accuracy: 0.7213 - val_loss: 0.8052
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6389 - loss: 0.8696 - val_accuracy: 0.7213 - val_loss: 0.6216
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6738 - loss: 0.8119 - val_accuracy: 0.7213 - val_loss: 0.6005
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6488 - loss: 0.8137 - val_accuracy: 0.7377 - val_loss: 0.6070
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6423 - loss: 0.7932 - val_accuracy: 0.7541 - val_loss: 0.5661
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6527 - loss: 0.7612 - val_accuracy: 0.7377 - val_loss: 0.5359
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6562 - loss: 0.7617 - val_accuracy: 0.7541 - val_loss: 0.5363
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6504 - loss: 0.7145 - val_accuracy: 0.7541 - val_loss: 0.5239
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6678 - loss: 0.6910 - val_accuracy: 0.7705 - val_loss: 0.5197
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6521 - loss: 0.6845 - val_accuracy: 0.7705 - val_loss: 0.5138
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6604 - loss: 0.6693 - val_accuracy: 0.7705 - val_loss: 0.5251
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6810 - loss: 0.6406 - val_accuracy: 0.7377 - val_loss: 0.5143
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6780 - loss: 0.6975 - val_accuracy: 0.7049 - val_loss: 0.5338
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6914 - loss: 0.6460 - val_accuracy: 0.7377 - val_loss: 0.5067
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6911 - loss: 0.6291 - val_accuracy: 0.7541 - val_loss: 0.5146
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6864 - loss: 0.6077 - val_accuracy: 0.7705 - val_loss: 0.5010
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7053 - loss: 0.5864 - val_accuracy: 0.7705 - val_loss: 0.4980
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6852 - loss: 0.6038 - val_accuracy: 0.7705 - val_loss: 0.4956
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6919 - loss: 0.6178 - val_accuracy: 0.7705 - val_loss: 0.5020
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6813 - loss: 0.5837 - val_accuracy: 0.7705 - val_loss: 0.4917
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7149 - loss: 0.5557 - val_accuracy: 0.7705 - val_loss: 0.4941
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7117 - loss: 0.5812 - val_accuracy: 0.7705 - val_loss: 0.4882
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7276 - loss: 0.5731 - val_accuracy: 0.7705 - val_loss: 0.4862
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7319 - loss: 0.5311 - val_accuracy: 0.7705 - val_loss: 0.4903
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7209 - loss: 0.5788 - val_accuracy: 0.7705 - val_loss: 0.4829
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7342 - loss: 0.5515 - val_accuracy: 0.7541 - val_loss: 0.4934
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7208 - loss: 0.5624 - val_accuracy: 0.7705 - val_loss: 0.4796

# %%
import numpy as np

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
import matplotlib.pyplot as plt

loss =model_history.history['loss'] # 훈련 데이터에서의 손실값
val_loss =model_history.history['val_loss'] # 테스트 데이터에서의 손실값
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73        27
#            1       0.78      0.82      0.80        34
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.76      0.77        61
# weighted avg       0.77      0.77      0.77        61
#
# [[19  8]
#  [ 6 28]]

# %%
from keras.optimizers import SGD,Adam

epoch_list = [10, 20]
batch_list = [16, 32]
optimizer_list = ['adam', 'sgd']

results = []

for epochs in epoch_list:
    for batch_size in batch_list:
        for opt_name in optimizer_list:
            print(f"▶ epochs={epochs}, batch_size={batch_size}, optimizer={opt_name}")
            optimizer = Adam() if opt_name == 'adam' else SGD()

            model = Sequential()
            model.add(Dense(32, input_shape=(13,), activation='relu'))
            model.add(Dense(8, activation='relu'))
            model.add(Dense(6, activation='relu'))
            model.add(Dense(2, activation='softmax'))

            model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

            history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
                                validation_data=(X_test, y_test), verbose=0)

            loss, acc = model.evaluate(X_test, y_test, verbose=0)
            print(f"Test Accuracy: {acc:.4f}\n")

            results.append({
                'epochs': epochs,
                'batch_size': batch_size,
                'optimizer': opt_name,
                'accuracy': acc
            })

df_result = pd.DataFrame(results)
df_result.sort_values(by='accuracy', ascending=False)
